# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from keras.datasets import fashion_mnist
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras import regularizers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import load_model

# %% [markdown]
# # Data Collection

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# # Data Annotation

# %%
class_labels = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Data Cleaning
#
#  - No missing values in Fashion MNIST.

# %% [markdown]
# Data Normalization

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# Train-Test Split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=2020)

# %% [markdown]
# Feature Extraction
#
#  - Done automatically by CNN layers.

# %% [markdown]
# Dimensionality Reduction

# %%
X_train = np.expand_dims(X_train, -1)
X_val   = np.expand_dims(X_val, -1)
X_test  = np.expand_dims(X_test, -1)

# %% [markdown]
# #  Image Augmentation

# %%
# Define ImageDataGenerator for training data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Fit the generator on training data
datagen.fit(X_train)

# %% [markdown]
# # **Callbacks Definitions**

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',factor=0.5,  patience=3, min_lr=1e-6, verbose=1)

# %% [markdown]
# # **Model Selection**

# %% [markdown]
# ## Base CNN Model

# %%
cnn_model = Sequential([
    Conv2D(32, 3, activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(2),
    Conv2D(64, 3, activation='relu', padding='same', strides=(2,2)),
    MaxPooling2D(2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(256, activation='relu'),
    Dropout(0.25),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 159,882
# Trainable params: 159,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile With Base CNN

# %%
cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Model Training With Base CNN

# %%
cnn_model.fit(X_train, y_train, epochs=20, batch_size=512, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 94/94 [==============================] - 2s 10ms/step - loss: 0.9928 - accuracy: 0.6290 - val_loss: 0.5649 - val_accuracy: 0.7810
# Epoch 2/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.5360 - accuracy: 0.7980 - val_loss: 0.4422 - val_accuracy: 0.8345
# Epoch 3/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4414 - accuracy: 0.8381 - val_loss: 0.3916 - val_accuracy: 0.8530
# Epoch 4/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3877 - accuracy: 0.8562 - val_loss: 0.3719 - val_accuracy: 0.8622
# Epoch 5/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3540 - accuracy: 0.8687 - val_loss: 0.3316 - val_accuracy: 0.8785
# Epoch 6/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3314 - accuracy: 0.8784 - val_loss: 0.3209 - val_accuracy: 0.8822
# Epoch 7/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3142 - accuracy: 0.8837 - val_loss: 0.3113 - val_accuracy: 0.8866
# Epoch 8/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2995 - accuracy: 0.8897 - val_loss: 0.3063 - val_accuracy: 0.8881
# Epoch 9/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2858 - accuracy: 0.8949 - val_loss: 0.2988 - val_accuracy: 0.8901
# Epoch 10/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2736 - accuracy: 0.8993 - val_loss: 0.2976 - val_accuracy: 0.8909
# Epoch 11/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2659 - accuracy: 0.9006 - val_loss: 0.2823 - val_accuracy: 0.8985
# Epoch 12/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2569 - accuracy: 0.9053 - val_loss: 0.2895 - val_accuracy: 0.8930
# Epoch 13/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2506 - accuracy: 0.9080 - val_loss: 0.2780 - val_accuracy: 0.8998
# Epoch 14/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2406 - accuracy: 0.9108 - val_loss: 0.2680 - val_accuracy: 0.9023
# Epoch 15/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2307 - accuracy: 0.9149 - val_loss: 0.2663 - val_accuracy: 0.9047
# Epoch 16/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2229 - accuracy: 0.9169 - val_loss: 0.2875 - val_accuracy: 0.8966
# Epoch 17/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2220 - accuracy: 0.9173 - val_loss: 0.2645 - val_accuracy: 0.9064
# Epoch 18/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2134 - accuracy: 0.9218 - val_loss: 0.2825 - val_accuracy: 0.9000
# Epoch 19/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2056 - accuracy: 0.9241 - val_loss: 0.2641 - val_accuracy: 0.9071
# Epoch 20/20
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1992 - accuracy: 0.9248 - val_loss: 0.2611 - val_accuracy: 0.9082

# %% [markdown]
# ## Model Evaluation With Base CNN

# %%
cnn_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2688 - accuracy: 0.9042
# [0.26877111196517944, 0.90420001745224]

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# Rebuild CNN model with updated hyperparameters
tuned_model = Sequential([
    Conv2D(64, 3, activation='relu', input_shape=(28,28,1)),  # Increased filters
    MaxPooling2D(2),
    Conv2D(128, 3, activation='relu', padding='same', strides=(2,2)), # More filters
    MaxPooling2D(2),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.3),                     # Higher dropout rate
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

tuned_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         73856
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_4 (Dense)             (None, 256)               295168
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 256)               65792
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 469,642
# Trainable params: 469,642
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile with tuned learning rate

# %%
tuned_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the tuned model tuning with Callbacks

# %%
tuned_model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=256,        # Batch size is a tunable hyperparameter
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/30
# 188/188 [==============================] - 2s 9ms/step - loss: 0.7821 - accuracy: 0.7054 - val_loss: 0.4610 - val_accuracy: 0.8294 - lr: 0.0010
# Epoch 2/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4256 - accuracy: 0.8445 - val_loss: 0.3527 - val_accuracy: 0.8702 - lr: 0.0010
# Epoch 3/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3514 - accuracy: 0.8725 - val_loss: 0.3273 - val_accuracy: 0.8793 - lr: 0.0010
# Epoch 4/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3125 - accuracy: 0.8852 - val_loss: 0.3091 - val_accuracy: 0.8875 - lr: 0.0010
# Epoch 5/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2833 - accuracy: 0.8956 - val_loss: 0.2944 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 6/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2592 - accuracy: 0.9041 - val_loss: 0.2843 - val_accuracy: 0.8976 - lr: 0.0010
# Epoch 7/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2407 - accuracy: 0.9113 - val_loss: 0.2631 - val_accuracy: 0.9063 - lr: 0.0010
# Epoch 8/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2253 - accuracy: 0.9164 - val_loss: 0.2579 - val_accuracy: 0.9085 - lr: 0.0010
# Epoch 9/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2120 - accuracy: 0.9197 - val_loss: 0.2666 - val_accuracy: 0.9073 - lr: 0.0010
# Epoch 10/30
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1970 - accuracy: 0.9260 - val_loss: 0.2550 - val_accuracy: 0.9107 - lr: 0.0010
# Epoch 11/30
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1842 - accuracy: 0.9321 - val_loss: 0.2631 - val_accuracy: 0.9125 - lr: 0.0010
# Epoch 12/30
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1743 - accuracy: 0.9344 - val_loss: 0.2675 - val_accuracy: 0.9107 - lr: 0.0010
# Epoch 13/30
# 188/188 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9379
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1671 - accuracy: 0.9379 - val_loss: 0.2666 - val_accuracy: 0.9121 - lr: 0.0010
# Epoch 14/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.1355 - accuracy: 0.9498 - val_loss: 0.2681 - val_accuracy: 0.9153 - lr: 5.0000e-04
# Epoch 15/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.1237 - accuracy: 0.9540 - val_loss: 0.2778 - val_accuracy: 0.9147 - lr: 5.0000e-04
# Epoch 16/30
# 182/188 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9572
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 188/188 [==============================] - 2s 8ms/step - loss: 0.1160 - accuracy: 0.9570 - val_loss: 0.2751 - val_accuracy: 0.9184 - lr: 5.0000e-04
# Epoch 17/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0960 - accuracy: 0.9648 - val_loss: 0.2680 - val_accuracy: 0.9198 - lr: 2.5000e-04
# Epoch 18/30
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0910 - accuracy: 0.9665 - val_loss: 0.2867 - val_accuracy: 0.9184 - lr: 2.5000e-04

# %% [markdown]
# ## Model Evaluation Tuning

# %%
tuned_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2634 - accuracy: 0.9064
# [0.2633913457393646, 0.9064000248908997]

# %% [markdown]
# # Model Optimization

# %%
# Define L2 regularization strength
l2_reg = 0.001

# Optimized CNN Model
optimized_model = Sequential([
    # Convolutional Block 1
    Conv2D(64, 3, activation='relu', input_shape=(28, 28, 1), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),

    # Convolutional Block 2
    Conv2D(128, 3, activation='relu', padding='same', strides=(2,2), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),

    # Convolutional Block 3
    Conv2D(64, 3, activation='relu', padding='same', strides=(1,1), kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    MaxPooling2D(2),
    
    Flatten(),

    # Dense Block 1
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.5),

    # Dense Block 2
    Dense(512, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.4),

    # Dense Block 3
    Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),
    Dropout(0.25),

    # Dense Block 4
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l2_reg)),
    BatchNormalization(),

    # Output
    Dense(10, activation='softmax')
])

# %% [markdown]
# ## Compile With Optimization

# %%
optimized_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Train the Model With Optimization

# %%
# Fit the model using data generator
history = optimized_model.fit(
    datagen.flow(X_train, y_train, batch_size=512),
    epochs=50,
    validation_data=(X_val, y_val),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 9s 81ms/step - loss: 2.1752 - accuracy: 0.6069 - val_loss: 4.4449 - val_accuracy: 0.1013 - lr: 0.0010
# Epoch 2/50
# 94/94 [==============================] - 8s 83ms/step - loss: 1.6372 - accuracy: 0.7437 - val_loss: 4.7639 - val_accuracy: 0.1663 - lr: 0.0010
# Epoch 3/50
# 94/94 [==============================] - 8s 80ms/step - loss: 1.3975 - accuracy: 0.7812 - val_loss: 4.1800 - val_accuracy: 0.2140 - lr: 0.0010
# Epoch 4/50
# 94/94 [==============================] - 8s 81ms/step - loss: 1.2040 - accuracy: 0.8019 - val_loss: 3.2342 - val_accuracy: 0.1894 - lr: 0.0010
# Epoch 5/50
# 94/94 [==============================] - 7s 79ms/step - loss: 1.0478 - accuracy: 0.8172 - val_loss: 2.1398 - val_accuracy: 0.3769 - lr: 0.0010
# Epoch 6/50
# 94/94 [==============================] - 7s 79ms/step - loss: 0.9122 - accuracy: 0.8315 - val_loss: 1.1196 - val_accuracy: 0.6952 - lr: 0.0010
# Epoch 7/50
# 94/94 [==============================] - 8s 80ms/step - loss: 0.8214 - accuracy: 0.8363 - val_loss: 0.8214 - val_accuracy: 0.8163 - lr: 0.0010
# Epoch 8/50
# 94/94 [==============================] - 7s 80ms/step - loss: 0.7475 - accuracy: 0.8410 - val_loss: 0.8588 - val_accuracy: 0.7512 - lr: 0.0010
# Epoch 9/50
# 94/94 [==============================] - 8s 82ms/step - loss: 0.6930 - accuracy: 0.8455 - val_loss: 0.6738 - val_accuracy: 0.8447 - lr: 0.0010
# Epoch 10/50
# 94/94 [==============================] - 7s 76ms/step - loss: 0
50
# 94/94 [==============================] - 7s 76ms/step - loss: 0.3272 - accuracy: 0.9057 - val_loss: 0.3363 - val_accuracy: 0.9033 - lr: 6.2500e-05
# Epoch 48/50
# 94/94 [==============================] - 7s 76ms/step - loss: 0.3237 - accuracy: 0.9071 - val_loss: 0.3366 - val_accuracy: 0.9043 - lr: 6.2500e-05
# Epoch 49/50
# 94/94 [==============================] - 7s 75ms/step - loss: 0.3194 - accuracy: 0.9083 - val_loss: 0.3313 - val_accuracy: 0.9058 - lr: 6.2500e-05
# Epoch 50/50
# 94/94 [==============================] - 7s 77ms/step - loss: 0.3189 - accuracy: 0.9090 - val_loss: 0.3212 - val_accuracy: 0.9087 - lr: 6.2500e-05

# %% [markdown]
# ## Model Evaluation With Optimization

# %%
optimized_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3353 - accuracy: 0.9044
# [0.3352586328983307, 0.9043999910354614]

# %% [markdown]
# # **Visualization and Evaluation**

# %% [markdown]
# ## Plot Training and Validation Accuracy & Loss

# %%
# Accuracy plot
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Display Sample Predictions

# %%
plt.figure(figsize=(16, 30))
j = 1
for i in np.random.randint(0, 1000, 60):
    plt.subplot(10, 6, j); j += 1
    plt.imshow(X_test[i].reshape(28, 28), cmap='Greys')
    plt.title('Actual = {} / {} \nPredicted = {} / {}'.format(
        class_labels[y_test[i]], y_test[i],
        class_labels[np.argmax(optimized_model.predict(np.expand_dims(X_test[i], axis=0)))],
        np.argmax(optimized_model.predict(np.expand_dims(X_test[i], axis=0)))
    ))
    plt.axis('off')
# Out:
# 1/1 [==============================] - 0s 467ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 999us/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# Predict Labels from Model

# %%
# Predict on test set
y_pred = optimized_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# Confusion Matrix

# %%
# Confusion confusion matrix
cm = confusion_matrix(y_test, y_pred_classes)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_test, y_pred_classes, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.86      0.85      0.86      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.90      0.84      0.87      1000
#        Dress       0.93      0.87      0.90      1000
#         Coat       0.82      0.86      0.84      1000
#       Sandal       0.99      0.97      0.98      1000
#        Shirt       0.69      0.75      0.72      1000
#      Sneaker       0.93      0.98      0.96      1000
#          Bag       0.97      0.99      0.98      1000
#   Ankle boot       0.98      0.94      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.91      0.90      0.91     10000
# weighted avg       0.91      0.90      0.91     10000

# %% [markdown]
# Accuracy Score

# %%
test_accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Test Accuracy Score: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy Score: 90.44%

# %% [markdown]
# # **Model Deployment**

# %% [markdown]
# Save the Entire Model (Recommended for deployment)

# %%
optimized_model.save('fashion_mnist_cnn_optimized_model.h5')

# %% [markdown]
# Load the Saved Model

# %%
# Load the trained model
loaded_model = load_model('fashion_mnist_cnn_optimized_model.h5')

# Predict on a single sample
sample = np.expand_dims(X_test[0], axis=0)
prediction = loaded_model.predict(sample)

print("Predicted Label:", np.argmax(prediction))
print("Actual Label:", y_test[0])
# Out:
# 1/1 [==============================] - 0s 114ms/step
# Predicted Label: 9
# Actual Label: 9
